# %% [markdown]
# <a href="https://colab.research.google.com/github/Souha-Kabtni/Work/blob/main/Copy_of_Copy_of_Work_IBE__Market.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import plotly.express as px

# %%
df = pd.read_excel('/content/drive/MyDrive/Coding_Dojo/Work/Task Advanced Find View 7-14-2023 7-47-29 PM.xlsx')
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#                    (Do Not Modify) Task  \
# 0  d1412d29-9d20-ee11-9cbc-6045bd080019
# 1  451c549e-a820-ee11-9cbc-6045bd080019
# 2  0546c7f0-a920-ee11-9cbc-6045bd080019
# 3  4c6defc7-ab20-ee11-9cbc-6045bd080019
# 4  1c7e0fca-af20-ee11-9cbc-6045bd080019
#
#                         (Do Not Modify) Row Checksum  \
# 0  LATdabyEeP4zqSqKCeFZnznCnz+PukqtkvXmEt/k81vJvG...
# 1  unxMm1YRUxEGa47uCGKfYqZEjquhe0myvdUO6JzNmHU42e...
# 2  TXwhcCALtd13+1tUXT9RZWmd4wOpBoroHAC5yuw1f15iET...
# 3  m4Q2Glbg4FVINdHPibgWwybivpAizA/doF5prI1EYiB1Ja...
# 4  t+7Fo7MQaCky0nxUhbW2f+TTWftm8vuuDPug44JAtjM08R...
#
#   (Do Not Modify) Modified On              Subject  Queue  Priority  \
# 0         2023-07-12 10:21:35  CEC – ES – CC delay    NaN       NaN
# 1         2023-07-12 11:38:31  CEC – ES – CC delay    NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   (Do Not Modify) Task          62 non-null     object
#  1   (Do Not Modify) Row Checksum  62 non-null     object
#  2   (Do Not Modify) Modified On   62 non-null     datetime64[ns]
#  3   Subject                       62 non-null     object
#  4   Queue                         0 non-null      float64
#  5   Priority                      0 non-null      float64
#  6   Task Status                   62 non-null     object
#  7   Task Country                  62 non-null     object
#  8   Auto Task                     62 non-null     object
#  9   Owner                         62 non-null     object
#  10  Created By                    62 non-null     object
#  11  Created On                    62 non-null     datetime64[ns]
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# (Do Not Modify) Task             0
# (Do Not Modify) Row Checksum     0
# (Do Not Modify) Modified On      0
# Subject                          0
# Queue                           62
# Priority                        62
# Task Status                      0
# Task Country                     0
# Auto Task                        0
# Owner                            0
# Created By                       0
# Created On                       0
# Case                            62
# Regarding                        0
# Actual End                      37
# Description                      0
# dtype: int64

# %%
# Queue                           62
# Priority                        62
# Case                            62

df = df.drop(columns=['Queue', 'Priority', 'Case', '(Do Not Modify) Task', '(Do Not Modify) Row Checksum', '(Do Not Modify) Modified On', 'Subject'])
df.head()
# Out:
#   Task Status Task Country            Auto Task                    Owner  \
# 0   Completed        Spain  CEC – ES – CC delay  Petra Kathrin Papenfuss
# 1   Completed        Spain  CEC – ES – CC delay  Petra Kathrin Papenfuss
# 2   Completed        Spain  CEC – ES – CC delay  Petra Kathrin Papenfuss
# 3   Completed        Spain  CEC – ES – CC delay  Petra Kathrin Papenfuss
# 4        Open        Spain  CEC – ES – CC delay  Petra Kathrin Papenfuss
#
#                 Created By          Created On   Regarding  \
# 0  Petra Kathrin Papenfuss 2023-07-12 11:16:32  5108044029
# 1  Petra Kathrin Papenfuss 2023-07-12 12:38:29  5107143810
# 2  Petra Kathrin Papenfuss 2023-07-12 12:47:57  5107973666
# 3  Petra Kathrin Papenfuss 2023-07-12 13:01:13  5106938950
# 4  Petra Kathrin Papenfuss 2023-07-12 13:29:55  5107381432
#
#            Actual End                                        Description
# 0 2023-07-12 11:21:35  ***********CEC Case Summary****************\nI...
# ...

# %%
df.isna().sum()

# Actual End is legitimate to be <62 since there are some open tasks
# => Question to Marwen: When a column's missing values are justified, how do we deal with it?
# Out:
# Task Status      0
# Task Country     0
# Auto Task        0
# Owner            0
# Created By       0
# Created On       0
# Regarding        0
# Actual End      37
# Description      0
# dtype: int64

# %%
df['Task Status'].value_counts()
# Out:
# Open         37
# Completed    25
# Name: Task Status, dtype: int64

# %%
# Graph for open and completed tasks

# sns.histplot(data = df, x = df['Task Status'], y = None);

fig1 = px.histogram(df, x = 'Task Status', y = None, color = 'Auto Task', title="Task Status vs. Auto Task", width=700, text_auto=True)
fig1.show()
fig1.write_html("plotly.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['Auto Task'].value_counts()
# Out:
# CEC – ES – DDS             44
# CEC – ES – CC delay         9
# CEC – ES – Part Missing     9
# Name: Auto Task, dtype: int64

# %%
# Data frame where columns are not combined using the groupby('Auto Task'):

df_Task_Des = df[['Auto Task', 'Description']]
df_Task_Des.head()
# Out:
#              Auto Task                                        Description
# 0  CEC – ES – CC delay  ***********CEC Case Summary****************\nI...
# 1  CEC – ES – CC delay  ***********CEC Case Summary****************\nI...
# 2  CEC – ES – CC delay  ***********CEC Case Summary****************\nI...
# 3  CEC – ES – CC delay  ***********CEC Case Summary****************\nI...
# 4  CEC – ES – CC delay  ***********CEC Case Summary****************\nI...

# %%
df_Task_Des.groupby('Auto Task').count()  # I like this data framed value_counts()
# Out:
#                          Description
# Auto Task
# CEC – ES – CC delay                9
# CEC – ES – DDS                    44
# CEC – ES – Part Missing            9

# %%
CEC_CC_delay = df_Task_Des['Auto Task'] == 'CEC – ES – CC delay'
print(CEC_CC_delay.sum())

CCC = df_Task_Des[df_Task_Des['Auto Task'] == 'CEC – ES – CC delay']
CCC.head()
# Out:
# 9
#              Auto Task                                        Description
# 0  CEC – ES – CC delay  ***********CEC Case Summary****************\nI...
# 1  CEC – ES – CC delay  ***********CEC Case Summary****************\nI...
# 2  CEC – ES – CC delay  ***********CEC Case Summary****************\nI...
# 3  CEC – ES – CC delay  ***********CEC Case Summary****************\nI...
# 4  CEC – ES – CC delay  ***********CEC Case Summary****************\nI...

# %%
CEC_DDS = df_Task_Des['Auto Task'] == 'CEC – ES – DDS'
print(CEC_DDS.sum())
DDS = df_Task_Des[df_Task_Des['Auto Task'] == 'CEC – ES – DDS']
DDS.head()
# Out:
# 44
#          Auto Task                                        Description
# 9   CEC – ES – DDS  ***********CEC Case Summary****************\nR...
# 10  CEC – ES – DDS  ***********CEC Case Summary****************\nR...
# 11  CEC – ES – DDS  ***********CEC Case Summary****************\nR...
# 12  CEC – ES – DDS  ***********CEC Case Summary****************\nR...
# 13  CEC – ES – DDS  ***********CEC Case Summary****************\nR...

# %%
CEC_Part_Missing = df_Task_Des['Auto Task'] == 'CEC – ES – Part Missing'
print(CEC_Part_Missing.sum())

PM = df_Task_Des[df_Task_Des['Auto Task'] == 'CEC – ES – Part Missing']
PM.head()
# Out:
# 9
#                   Auto Task                                        Description
# 53  CEC – ES – Part Missing  ***********CEC Case Summary****************\nM...
# 54  CEC – ES – Part Missing  ***********CEC Case Summary****************\nM...
# 55  CEC – ES – Part Missing  ***********CEC Case Summary****************\nM...
# 56  CEC – ES – Part Missing  ***********CEC Case Summary****************\nM...
# 57  CEC – ES – Part Missing  ***********CEC Case Summary****************\nM...

# %%
# Not used since it will ulter changes in my regEx results

# df_gourped = df[['Auto Task', 'Description']].groupby('Auto Task').sum().reset_index()   #This is not bad to gather all the notes per Auto task (df_Task_Des.groupby('Auto Task').Age.sum())
# df_gourped

# CCC = df_Task_Des[df_Task_Des['Auto Task'] == 'CEC – ES – CC delay']
# CCC.head()

# %%
# Gather all my last statuses
Root_Cause = ['@[agedemail]','@[MATEXescalation]', '@[LOGinvestigation]', '@[WO submitted]', '@[ContactRequest]', '@[Sol30informed]', '@[WrongPudo]', '@[alt suggested]', '@[KCIPrompt]', '@[Altpartrequested]']
Root_Cause
# Out:
# ['@[agedemail]',
#  '@[MATEXescalation]',
#  '@[LOGinvestigation]',
#  '@[WO submitted]',
#  '@[ContactRequest]',
#  '@[Sol30informed]',
#  '@[WrongPudo]',
#  '@[alt suggested]',
#  '@[KCIPrompt]',
#  '@[Altpartrequested]']

# %%
Mail = df_Task_Des['Description'].str.contains('@[agedemail]',regex=False, case = False).sum()
Matex = df_Task_Des['Description'].str.contains('@[MATEXescalation]',regex=False, case = False).sum()
Log = df_Task_Des['Description'].str.contains('@[LOGinvestigation]',regex=False, case = False).sum()
WO_sub = df_Task_Des['Description'].str.contains('@[WO submitted]',regex=False, case = False).sum()
Contact_req = df_Task_Des['Description'].str.contains('@[ContactRequest]',regex=False, case = False).sum()
Sol30 = df_Task_Des['Description'].str.contains('@[Sol30informed]',regex=False, case = False).sum()
Wrong_PUDO = df_Task_Des['Description'].str.contains('@[WrongPudo]',regex=False, case = False).sum()
Alt_part_sug = df_Task_Des['Description'].str.contains('@[alt suggested]',regex=False, case = False).sum()
KCI = df_Task_Des['Description'].str.contains('@[KCIPrompt]',regex=False, case = False).sum()
Alt_part_req = df_Task_Des['Description'].str.contains('@[Altpartrequested]',regex=False, case = False).sum()


# Let us try to combine them ALL in 1 code via Filtering!
# What is wrong with this???

## L_S = df_gourped.loc[[Mail | Matex | Log | WO_sub | Contact_req | Sol30 | Wrong_PUDO | Alt_part_sug | KCI | Alt_part_req]]
## L_S

# %%
# LS = {'@[agedemail]': [Mail],
     # '@[MATEXescalation]' : [Matex],
     # '@[LOGinvestigation]': [Log],
     # '@[WO submitted]' : [WO_sub],
     # '@[ContactRequest]' : [Contact_req],
     # '@[Sol30informed]': [Sol30],
     # '@[WrongPudo]' : [Wrong_PUDO],
     # '@[alt suggested]': [Alt_part_sug],
     # '@[KCIPrompt]': [KCI],
     # '@[Altpartrequested]': [Alt_part_req]}

# df_L_S = pd.DataFrame(LS) # OR without the [] for each key, just write: df_L_S = pd.DataFrame(LS, index=[0])
# print(df_L_S)

# %%
LS = {'Root_Cause' : ['@[agedemail]','@[MATEXescalation]', '@[LOGinvestigation]', '@[WO submitted]', '@[ContactRequest]', '@[Sol30informed]', '@[WrongPudo]', '@[alt suggested]', '@[KCIPrompt]', '@[Altpartrequested]'],
       'Frequency' : [Mail, Matex, Log,  WO_sub, Contact_req, Sol30, Wrong_PUDO, Alt_part_sug, KCI, Alt_part_req]}

df_L_S = pd.DataFrame(LS)
df_L_S.head()
# Out:
#             Root_Cause  Frequency
# 0         @[agedemail]          1
# 1   @[MATEXescalation]         15
# 2  @[LOGinvestigation]         14
# 3      @[WO submitted]          6
# 4    @[ContactRequest]          6

# %%
fig2 = px.bar(df_L_S, x = None, y = 'Frequency', color = 'Root_Cause', title="TASKS BY ROOT CAUSE​", width=700, text_auto=True)  # df_L_S2.sort_values(by='Frequency')
fig2.show()
fig2.write_html("plotly.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Merge > Join 2 DataFrames

# inner = pd.concat([df_Task_Des, df_L_S2], ignore_index = True)
# inner

# %%
figtest = px.histogram(df_Task_Des, x = 'Auto Task', y = None, title="?", width=700, text_auto=True)  # df_L_S2.sort_values(by='Frequency')
figtest.show()
figtest.write_html("plotly.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
words = df_Task_Des['Description'].str.findall(r'@\[(.*?)\]', flags=re.IGNORECASE)
words
# Out:
# 0                     []
# 1                     []
# 2                     []
# 3                     []
# 4            [agedemail]
#              ...
# 57                    []
# 58                    []
# 59    [Altpartrequested]
# 60           [KCIprompt]
# 61           [KCIprompt]
# Name: Description, Length: 62, dtype: object

# %%
word_counts = pd.Series([w.lower() for s in words for w in s]).value_counts()
word_counts
# Out:
# matexescalation     29
# loginvestigation    25
# sol30informed       12
# wo submitted         7
# contactrequest       6
# kciprompt            4
# wrongpudo            3
# agedemail            1
# alt suggested        1
# agedmail             1
# altpartrequested     1
# dtype: int64

# %%
# df_Task_Des_WC = word_counts.to_frame(name="W_C").reset_index()
# df_Task_Des_WC

# %%
# Adding a Pandas Column with More Complicated Conditions
df_Task_Des2 = df_Task_Des.assign(WC=word_counts)
df_Task_Des2
# Out:
#                   Auto Task  \
# 0       CEC – ES – CC delay
# 1       CEC – ES – CC delay
# 2       CEC – ES – CC delay
# 3       CEC – ES – CC delay
# 4       CEC – ES – CC delay
# ..                      ...
# 57  CEC – ES – Part Missing
# 58  CEC – ES – Part Missing
# 59  CEC – ES – Part Missing
# 60  CEC – ES – Part Missing
# 61  CEC – ES – Part Missing
#
#                                           Description  WC
# 0   ***********CEC Case Summary****************\nI... NaN
# 1   ***********CEC Case Summary****************\nI... NaN
# 2   ***********CEC Case Summary****************\nI... NaN
# 3   ***********CEC Case Summary****************\nI... NaN
# 4   ***********CEC Case Summary****************\nI... NaN
# ..                                                ...  ..
# 57  ***********CEC Case Summary****************\nM... NaN
# 58  ***********CEC Case Summary****************\nM... NaN
# 59  ***********CEC Case Summary****************\nM... NaN
# ...

# %%
figtest = px.histogram(df_Task_Des2, x = 'Auto Task', y = 'WC', title="?", width=700, text_auto=True)  # df_L_S2.sort_values(by='Frequency')
figtest.show()
figtest.write_html("plotly.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_Task_Des_WC = word_counts.to_frame(name="W_C").reset_index()
df_Task_Des_WC
# Out:
#                index  W_C
# 0    matexescalation   29
# 1   loginvestigation   25
# 2      sol30informed   12
# 3       wo submitted    7
# 4     contactrequest    6
# 5          kciprompt    4
# 6          wrongpudo    3
# 7          agedemail    1
# 8      alt suggested    1
# 9           agedmail    1
# 10  altpartrequested    1

# %%
df_Task_Des_WC = word_counts.to_frame(name="W_C").reset_index()
df_Task_Des_WC

# a Viz from this seperate dataframe

figtest = px.histogram(df_Task_Des_WC, x = 'index', y = 'W_C', title="TASKS BY ROOT CAUSE", width=1000, text_auto=True,
                       labels={'index': 'Root Cause',
                               'W_C': 'Frequency'})  # df_L_S2.sort_values(by='Frequency')
figtest.show()
figtest.write_html("plotly.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
CCC_Test = CCC['Description'].str.findall(r'@\[(.*?)\]', flags=re.IGNORECASE).value_counts()
CCC_Test

# %%
DDS_Test = DDS['Description'].str.findall(r'@\[(.*?)\]', flags=re.IGNORECASE)
DDS_Test.value_counts()

# %%
PM_Test = PM['Description'].str.findall(r'@\[(.*?)\]', flags=re.IGNORECASE)
PM_Test

# %%
df_gourped = df_Task_Des[['Auto Task', 'Description']].groupby('Auto Task').sum().reset_index()
df_gourped

# %%
# add a column where I put Dhia's created code

CEC_CC_delay = df_Task_Des['Auto Task'] == 'CEC – ES – CC delay'

df_gourped_add = df_gourped['Auto Task']
df_gourped_add
# Out:
# 0        CEC – ES – CC delay
# 1             CEC – ES – DDS
# 2    CEC – ES – Part Missing
# Name: Auto Task, dtype: object

# %%
df_Task_Des

# %%
figtest = px.histogram(df_Task_Des, x = 'Auto Task', y = 'words', title="?", width=700, text_auto=True)  # df_L_S2.sort_values(by='Frequency')
figtest.show()
figtest.write_html("plotly.html")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-143-45c4b19c216f> in <cell line: 1>()
# ----> 1 figtest = px.histogram(df_Task_Des, x = 'Auto Task', y = 'words', title="?", width=700, text_auto=True)  # df_L_S2.sort_values(by='Frequency')
#       2 figtest.show()
#       3 figtest.write_html("plotly.html")
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_chart_types.py in histogram(data_frame, x, y, color, pattern_shape, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, pattern_shape_sequence, pattern_shape_map, marginal, opacity, orientation, barmode, barnorm, histnorm, log_x, log_y, range_x, range_y, histfunc, cumulative, nbins, text_auto, title, template, width, height)
# ...

# %%
# df_Task_Des.groupby('Auto Task')['Description'].str.contains('@[MATEXescalation]',regex=False, case = False)

# %%
# Root_Cause_Calculation = [Mail, Matex, Log, WO_sub, Contact_req, Sol30, Wrong_PUDO, Alt_part_sug, KCI, Alt_part_req]

# df_Task_Des = df_Task_Des.assign(Root_Cause_CalculationM = df_Task_Des['Description'].str.contains('@[MATEXescalation]',regex=False, case = False).sum())


# df_Task_Des['Root Cause Calculation'] = df.apply(lambda x: Root_Cause_Calculation, axis = 2)

# %%
# Useful for the next code

Mail = df_Task_Des['Description'].str.contains('@[agedemail]',regex=False, case = False).sum()
Matex = df_Task_Des['Description'].str.contains('@[MATEXescalation]',regex=False, case = False).sum()
Log = df_Task_Des['Description'].str.contains('@[LOGinvestigation]',regex=False, case = False).sum()
WO_sub = df_Task_Des['Description'].str.contains('@[WO submitted]',regex=False, case = False).sum()
Contact_req = df_Task_Des['Description'].str.contains('@[ContactRequest]',regex=False, case = False).sum()
Sol30 = df_Task_Des['Description'].str.contains('@[Sol30informed]',regex=False, case = False).sum()
Wrong_PUDO = df_Task_Des['Description'].str.contains('@[WrongPudo]',regex=False, case = False).sum()
Alt_part_sug = df_Task_Des['Description'].str.contains('@[alt suggested]',regex=False, case = False).sum()
KCI = df_Task_Des['Description'].str.contains('@[KCIPrompt]',regex=False, case = False).sum()
Alt_part_req = df_Task_Des['Description'].str.contains('@[Altpartrequested]',regex=False, case = False).sum()

# %%
# 7th way to search Multiple words in the Description column and put their number of occurence in a new column!

def R_C(x):
  if x == Mail:
    return x.sum()
  elif x == Matex:
    return x.sum()
  elif x == Log:
    return x.sum()
  elif x == WO_sub:
    return x.sum()
  elif x == Contact_req:
    return x.sum()
  elif x == Sol30:
    return x.sum()
  elif x == Wrong_PUDO:
    return x.sum()
  elif x == Alt_part_sug:
    return x.sum()
  elif x == KCI:
    return x.sum()
  elif x == Alt_part_req:
    return x.sum()

  else # Move the next row! Not sure if this is indeed needed with apply() function

df_Task_Des['Root_Cause1'] = df_Task_Des['Description'].apply(R_C)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-53c201ce61a2> in <cell line: 8>()
#       6
#       7
# ----> 8 df_Task_Des['Root_Cause1'] = df_Task_Des['Description'].apply(R_C)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1121
#    1122         # self.f is Callable
# -> 1123         return self.apply_standard()
#    1124
#    1125     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1172             else:
#    1173                 values = obj.astype(object)._values
# ...

# %%
# 1st way to search Multiple words in the Description column
# Gave me an empty table


# df_Task_Des[df_Task_Des['Description'].str.contains('agedemail | Altpartrequested',regex=False, case = False)]    # |    (df_Task_Des['Description'].str.contains('@[MATEXescalation]\.'))]

# %%
# 2nd way to search Multiple words in the Description column
# Gave me 0


# df_Task_Des['Description'].str.contains('@[agedemail]\. | @[Altpartrequested]\.',regex=False, case = False).sum()   # |    (df_Task_Des['Description'].str.contains('@[MATEXescalation]\.'))]

# %%
# 3rd way to search Multiple words in the Description column
# Gave me 0


# Root_Cause = ['@[agedemail]','@[MATEXescalation]', '@[LOGinvestigation]', '@[WO submitted]', '@[ContactRequest]', '@[Sol30informed]', '@[WrongPudo]', '@[alt suggested]', '@[KCIPrompt]', '@[Altpartrequested]']

# regstr = '|'.join(Root_Cause)

# df_Task_Des['Description'].str.upper().str.contains(regstr).sum()

# %%
# 4th way to search Multiple words in the Description column
# Gave me an error: AttributeError: 'DataFrame' object has no attribute 'str'


# DDS.astype(str).str.extractall(
#    '({})'.format('|'.join(Root_Cause))
# ).groupby(level=0)[0].value_counts().unstack(fill_value=0)

# %%
# 5th way to search Multiple words in the Description column
# Gave me an error: AttributeError: 'DataFrame' object has no attribute 'str'


# DDS.astype(str).str.extractall('({})'.format('|'.join(Root_Cause)))\
  #                         .iloc[:, 0].str.get_dummies().sum(level=0)

# %%
# 6th way to search Multiple words in the Description column


# index_Description = df_Task_Des.columns.get_loc('Description')
# index_Auto_Task = df_Task_Des.columns.get_loc('Auto Task')

# print(index_Description, index_Auto_Task)


# ==> Gave me results: 1 0


# Define the Pattern on the Data

# data_pattern = r'([@\[\]])'


# ==> Passed YET I need to re-check the correct pattern/formula

# Look for Data in DataFrame
# Iterate through => for loop

# for row in range(0, len(df_Task_Des)):
#   df_Task_Des = re.search(data_pattern, df_Task_Des.iat[row, index_Description]).group()
#   df_Task_Des.iat[row, index_Auto_Task] = df_Task_Des

# Gave me an error: AttributeError: 'str' object has no attribute 'iat'
